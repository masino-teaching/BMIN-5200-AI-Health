# %%
# mount the google drive - this is necessary to access supporting src
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
! pip install ucimlrepo

# %%
! pip install tableone

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
from tableone import TableOne, load_dataset

# %% [markdown]
# # Fetch dataset
#
# Using the ucimlrepo package, fetch heart disease dataset from UC Irvine Machine Learning Repository.

# %%
# fetch dataset
heart_disease = fetch_ucirepo(id=45)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Inspect the data
#
# Using Pandas methods, inspect the features and their statistics.

# %%
X.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
X.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# ...

# %% [markdown]
# # Develop a Table 1
#
# We'll use the tableone package to create a Table 1 object. As we will later develop a simple binary calssifier with this data, we'll first convert the target (y) to a binary value by assigning samples with num=0 to class 0, and samples with num>0 to class 1. We'll do this in a no variable, all_data, so as to not corrupt the raw data.

# %%
all_data = pd.concat((y>=1,X), axis=1).rename(columns={'num':'heart_disease'})
all_data['heart_disease'] = all_data['heart_disease'].astype(int)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# let's take a look at the new datafram to make sure things are as expected
all_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    heart_disease  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0              0   63    1   1       145   233    1        2      150      0
# 1              1   67    1   4       160   286    0        2      108      1
# 2              1   67    1   4       120   229    0        2      129      1
# 3              0   37    1   3       130   250    0        0      187      0
# 4              0   41    0   2       130   204    0        2      172      0
#
#    oldpeak  slope   ca  thal
# 0      2.3      3  0.0   6.0
# 1      1.5      2  3.0   3.0
# 2      2.6      2  2.0   7.0
# 3      3.5      3  0.0   3.0
# ...

# %%
# save all_data to a .csv file for use in Orange
fn = "/content/drive/MyDrive/Colab Notebooks/bmin5200-2023/demos/colab-versions/UCI-heart-disease.csv"
all_data.to_csv(fn, index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We are finally ready to create the Table 1. After creating the Table 1 object in Python, we can save it to various formats for dissemination.

# %%
# let's create the Table 1
table1 = TableOne(all_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# now we can view Table 1 in line
table1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           Missing       Overall
# n                                           303
# heart_disease, mean (SD)        0     0.5 (0.5)
# age, mean (SD)                  0    54.4 (9.0)
# sex, mean (SD)                  0     0.7 (0.5)
# cp, mean (SD)                   0     3.2 (1.0)
# trestbps, mean (SD)             0  131.7 (17.6)
# chol, mean (SD)                 0  246.7 (51.8)
# fbs, mean (SD)                  0     0.1 (0.4)
# restecg, mean (SD)              0     1.0 (1.0)
# thalach, mean (SD)              0  149.6 (22.9)
# exang, mean (SD)                0     0.3 (0.5)
# ...

# %%
# we can also save this table 1 in various formats
fn = "/content/drive/MyDrive/Colab Notebooks/bmin5200-2023/demos/colab-versions/tableone_demo.html"
table1.to_html(fn)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(table1.tabulate(tablefmt = "github"))
# Out:
# |                          |    | Missing   | Overall      |
# |--------------------------|----|-----------|--------------|
# | n                        |    |           | 303          |
# | heart_disease, mean (SD) |    | 0         | 0.5 (0.5)    |
# | age, mean (SD)           |    | 0         | 54.4 (9.0)   |
# | sex, mean (SD)           |    | 0         | 0.7 (0.5)    |
# | cp, mean (SD)            |    | 0         | 3.2 (1.0)    |
# | trestbps, mean (SD)      |    | 0         | 131.7 (17.6) |
# | chol, mean (SD)          |    | 0         | 246.7 (51.8) |
# | fbs, mean (SD)           |    | 0         | 0.1 (0.4)    |
# | restecg, mean (SD)       |    | 0         | 1.0 (1.0)    |
# | thalach, mean (SD)       |    | 0         | 149.6 (22.9) |
# | exang, mean (SD)         |    | 0         | 0.3 (0.5)    |
# | oldpeak, mean (SD)       |    | 0         | 1.0 (1.2)    |
# | slope, mean (SD)         |    | 0         | 1.6 (0.6)    |
# ...

# %%
print(table1.tabulate(tablefmt = "latex"))
# Out:
# \begin{tabular}{llll}
# \hline
#                           &    & Missing   & Overall      \\
# \hline
#  n                        &    &           & 303          \\
#  heart\_disease, mean (SD) &    & 0         & 0.5 (0.5)    \\
#  age, mean (SD)           &    & 0         & 54.4 (9.0)   \\
#  sex, mean (SD)           &    & 0         & 0.7 (0.5)    \\
#  cp, mean (SD)            &    & 0         & 3.2 (1.0)    \\
#  trestbps, mean (SD)      &    & 0         & 131.7 (17.6) \\
#  chol, mean (SD)          &    & 0         & 246.7 (51.8) \\
#  fbs, mean (SD)           &    & 0         & 0.1 (0.4)    \\
#  restecg, mean (SD)       &    & 0         & 1.0 (1.0)    \\
#  thalach, mean (SD)       &    & 0         & 149.6 (22.9) \\
#  exang, mean (SD)         &    & 0         & 0.3 (0.5)    \\
#  oldpeak, mean (SD)       &    & 0         & 1.0 (1.2)    \\
#  slope, mean (SD)         &    & 0         & 1.6 (0.6)    \\
#  ca, mean (SD)            &    & 4         & 0.7 (0.9)    \\
# ...
